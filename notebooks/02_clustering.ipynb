# %%
import polars as pl

# Load your cleaned dataset
df = pl.read_csv("../data/processed_features.csv")

df.head()
# Out:
# shape: (5, 4)
# ┌────────────┬─────────┬───────────┬──────────┐
# │ CustomerID ┆ Recency ┆ Frequency ┆ Monetary │
# │ ---        ┆ ---     ┆ ---       ┆ ---      │
# │ i64        ┆ i64     ┆ i64       ┆ f64      │
# ╞════════════╪═════════╪═══════════╪══════════╡
# │ 14824      ┆ 9       ┆ 4         ┆ 1127.71  │
# │ 12353      ┆ 203     ┆ 1         ┆ 89.0     │
# │ 16143      ┆ 2       ┆ 7         ┆ 2419.84  │
# │ 13243      ┆ 202     ┆ 1         ┆ 600.07   │
# │ 15101      ┆ 8       ┆ 3         ┆ 310.03   │
# └────────────┴─────────┴───────────┴──────────┘

# %%
X = df.drop("CustomerID").to_numpy()

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)

# %%
import hdbscan

clusterer = hdbscan.HDBSCAN(min_cluster_size=50)
labels = clusterer.fit_predict(X_scaled)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import hdbscan
#       3 clusterer = hdbscan.HDBSCAN(min_cluster_size=50)
#       4 labels = clusterer.fit_predict(X_scaled)
#
# ModuleNotFoundError: No module named 'hdbscan'
